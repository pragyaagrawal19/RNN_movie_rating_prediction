# %%
import tensorflow as tf
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing import sequence
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Embedding, SimpleRNN, Dense
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 import tensorflow as tf
# ----> 2 from tensorflow.keras.datasets import imdb
#       3 from tensorflow.keras.preprocessing import sequence
#       4 from tensorflow.keras.models import Sequential, load_model
#       5 from tensorflow.keras.layers import Embedding, SimpleRNN, Dense
#
# ModuleNotFoundError: No module named 'tensorflow.keras'

# %%
word_index = imdb.get_word_index()
reverse_word_index = {value:key for (key,value) in word_index.items()}
model= load_model('simple_rnn_imdb.h5')
model.summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 word_index = imdb.get_word_index()
#       2 reverse_word_index = {value:key for (key,value) in word_index.items()}
#       3 model= load_model('simple_rnn_imdb.h5')
#       4 model.summary()
#
# NameError: name 'imdb' is not defined

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 2
#       1 import tensorflow as tf
# ----> 2 print(tf.__version__)
#
# AttributeError: module 'tensorflow' has no attribute '__version__'

# %%
import tensorflow as tf
import sys
print(sys.executable)
print(tf.__version__)
# Out:
# /Users/shikhar/Documents/Churn_modeling_with_ann/venv/bin/python
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 4
#       1 import tensorflow as tf
#       2 import sys
#       3 print(sys.executable)
# ----> 4 print(tf.__version__)
#
# AttributeError: module 'tensorflow' has no attribute '__version__'
